# %% [markdown]
# # ***Operators in Python***
#
#
# *   operators - they are symbols which are used to perform certain task or activity
# *   operands  - they are the values on which we are going to perform operations
# *   operation - it is a procedure in which we will perform some operation on two or more operands
#
#
# # Types of Operators in Python -
#
#
# 1.   Arithmetic Operators - +, -, *, /, //, **, %
# 2.   Assignment Operators - +=, -=, *=, /=, //=, **=, %=, =
# 3.   Comparision Operators - <, >, <=, >=, ==, !=
# 4.   Logical Operators - AND, OR, NOT
# 5.   Membership Operators - in, not in
# 6.   Identity Operators - is, is not
# 7.   Bitwise Operators  - & (AND), | (OR), ^ (XOR)

# %%
# 1. Arithmetic Operator - +, -, *, /, //, **, %

# + :
# num1 = 42
# num2 = 85

# result = num1 + num2

# print("After adding both the variables -", result)

# - :
# num1 = int(input("Enter a number - "))
# print(num1)
# print(type(num1))
# num2 = float(input("Enter a number - "))

# result = num1 - num2

# print("After subtracting both the variables -", result)

# * :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# result = num1 * num2

# print("After product both the variables -", result)

# / :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# result = num1 / num2

# print("After division both the variables -", result)

# // : floor division
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# result = num1 // num2

# print("After floor-division both the variables -", result)

# ** : Exponential
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# result = num1 ** num2

# print("After exponential both the variables -", result)

# % : Modulus
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# result = num1 % num2

# print("After modulus both the variables -", result)

# %%
# 2. Assignment Operators - =, +=, -+, *=, /=, //=, **=, %=


# # += :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# num1 += num2     # num1 = num1 + num2

# print("After += both the variables -", num1)


# # -= :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# num1 -= num2     # num1 = num1 - num2

# print("After += both the variables -", num1)


# # *= :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# num1 *= num2     # num1 = num1 * num2

# print("After *= both the variables -", num1)


# # += :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# num1 /= num2     # num1 = num1 / num2

# print("After /= both the variables -", num1)


# //= :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# num1 //= num2     # num1 = num1 // num2

# print("After //= both the variables -", num1)


# # **= :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# num1 **= num2     # num1 = num1 ** num2

# print("After **= both the variables -", num1)


# %= :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# num1 %= num2     # num1 = num1 % num2

# print("After %= both the variables -", num1)

# %%
# Comparison Operators - <, >, <=, >=, ==, !=

# # < :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# print("num1 is lesser than num2 or not -", num1 < num2)

# # > :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# print("num1 is greator than num2 or not -", num1 > num2)

# # <= :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# print("num1 is lesser or equals to num2 or not -", num1 <= num2)

# # >= :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# print("num1 is greator or equals to num2 or not -", num1 >= num2)

# # == :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# print("num1 is isequals to num2 or not -", num1 == num2)

# # != :
# num1 = float(input("Enter a number - "))
# num2 = float(input("Enter a number - "))

# print("num1 is is not equals to num2 or not -", num1 != num2)

# %%
# Logical Operators - and | or | not
# and operator - strict conditions follow hoti hai!
# num1 = 75
# num2 = 20
# num3 = 422

# print(num1 > num2 and num1 > num3)


# or operator - atleast one condtion must be satisfied
# num1 = 75
# num2 = 20
# num3 = 422

# print(num1 > num2 and num1 > num3)


# not operator - it will reverse the resultant output
# num1 = 75
# num2 = 20
# num3 = 422

# print(not(num1 > num2 and num1 > num3))
# print(num1 > num2 and not num1 > num3)
# print(num1 > num2 or not num1 < num3)

# %%
# # Membership operators - In | Not In - it will only check the value of the variable or string or integer value that user had provided
# carList1 = ["Mercedes Benz", "BMW", "Ferrari"]
# carList2 = [["Mercedes Benz", "BMW", "Ferrari"], "Jaguar", "Defender"]
# carList3 = carList1
# # print("ferrari" in carList)

# # print("ferrari" not in carList)

# # print(carList1 in carList2)
# # print(carList2 in carList1)
# print(carList1 in carList3)

# %%
# Identity Operators - Is | Is Not - it will check the value as well as memory allocation
# carList1 = ["Mercedes Benz", "BMW", "Ferrari"]
# carList2 = ["Mercedes Benz", "BMW", "Ferrari"]
# carList3 = carList1
# print("ferrari" is carList)

# print("ferrari" is not carList)

# print(carList1 is carList2)
# print(carList2 is carList1)
# print(carList1 is carList3)
