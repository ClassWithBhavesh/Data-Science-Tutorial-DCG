# %% [markdown]
# # **Some Pandas Methods With lil bit of analaysis**

# %%
import pandas as pd

# %%
df = pd.read_csv("purchase_prices.csv")
df
# Out:
#        Brand                   Description  Price    Size Volume  \
# 0         58   Gekkeikan Black & Gold Sake  12.99   750mL    750
# 1         62      Herradura Silver Tequila  36.99   750mL    750
# 2         63    Herradura Reposado Tequila  38.99   750mL    750
# 3         72          No. 3 London Dry Gin  34.99   750mL    750
# 4         75     Three Olives Tomato Vodka  14.99   750mL    750
# ...      ...                           ...    ...     ...    ...
# 12256  44917     Ferreira 10-Yr Tawny Port  24.99   750mL    750
# 12257  44944     Sanford Santa Rita Pnt Nr  22.99   750mL    750
# 12258  45016  Neal One Lane Bridg Cab Svgn  93.99   750mL    750
# 12259  46011       Folonari Pnt Nr Venezie  12.99  1500ml   1500
# 12260  46964     Calera Viognier Mt Harlan  35.99   750mL    750
#
#        Classification  PurchasePrice  VendorNumber  \
# 0                   1           9.28          8320
# 1                   1          28.67          1128
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Brand         Price  Classification  PurchasePrice  \
# count  12261.000000  12261.000000    12261.000000   12261.000000
# mean   17989.067123     38.640240        1.708996      26.488220
# std    12528.503464    206.151172        0.454244     156.182948
# min       58.000000      0.000000        1.000000       0.000000
# 25%     5990.000000     10.990000        1.000000       6.890000
# 50%    18788.000000     15.990000        2.000000      10.650000
# 75%    25117.000000     29.990000        2.000000      20.130000
# max    90631.000000  13999.900000        2.000000   11111.030000
#
#         VendorNumber
# count   12261.000000
# mean    10814.861757
# std     19007.682322
# min         2.000000
# 25%      3960.000000
# 50%      7153.000000
# 75%      9552.000000
# max    173357.000000

# %%
df.describe(include='all')
# Out:
#                Brand           Description         Price   Size Volume  \
# count   12261.000000                 12260  12261.000000  12260  12260
# unique           NaN                 11114           NaN     56     33
# top              NaN  Bacardi Superior Rum           NaN  750mL    750
# freq             NaN                     7           NaN   9823   9840
# mean    17989.067123                   NaN     38.640240    NaN    NaN
# std     12528.503464                   NaN    206.151172    NaN    NaN
# min        58.000000                   NaN      0.000000    NaN    NaN
# 25%      5990.000000                   NaN     10.990000    NaN    NaN
# 50%     18788.000000                   NaN     15.990000    NaN    NaN
# 75%     25117.000000                   NaN     29.990000    NaN    NaN
# max     90631.000000                   NaN  13999.900000    NaN    NaN
#
#         Classification  PurchasePrice   VendorNumber             VendorName
# ...

# %%
df.count()
# Out:
# Brand             12261
# Description       12260
# Price             12261
# Size              12260
# Volume            12260
# Classification    12261
# PurchasePrice     12261
# VendorNumber      12261
# VendorName        12261
# dtype: int64

# %%
df['VendorNumber'].unique().size
# Out:
# 131

# %%
df['VendorName'].unique().size
# Out:
# 136

# %%
newDf = df.drop(axis=1, columns="Volume")

# %%
newDf
# Out:
#        Brand                   Description  Price    Size  Classification  \
# 0         58   Gekkeikan Black & Gold Sake  12.99   750mL               1
# 1         62      Herradura Silver Tequila  36.99   750mL               1
# 2         63    Herradura Reposado Tequila  38.99   750mL               1
# 3         72          No. 3 London Dry Gin  34.99   750mL               1
# 4         75     Three Olives Tomato Vodka  14.99   750mL               1
# ...      ...                           ...    ...     ...             ...
# 12256  44917     Ferreira 10-Yr Tawny Port  24.99   750mL               2
# 12257  44944     Sanford Santa Rita Pnt Nr  22.99   750mL               2
# 12258  45016  Neal One Lane Bridg Cab Svgn  93.99   750mL               2
# 12259  46011       Folonari Pnt Nr Venezie  12.99  1500ml               2
# 12260  46964     Calera Viognier Mt Harlan  35.99   750mL               2
#
#        PurchasePrice  VendorNumber                   VendorName
# ...

# %%
df.drop(axis=1, columns="Size", inplace=True)

# %%
df.drop(axis=1, columns="Volume", inplace=True)

# %%
df
# Out:
#        Brand                   Description  Price  Classification  \
# 0         58   Gekkeikan Black & Gold Sake  12.99               1
# 1         62      Herradura Silver Tequila  36.99               1
# 2         63    Herradura Reposado Tequila  38.99               1
# 3         72          No. 3 London Dry Gin  34.99               1
# 4         75     Three Olives Tomato Vodka  14.99               1
# ...      ...                           ...    ...             ...
# 12256  44917     Ferreira 10-Yr Tawny Port  24.99               2
# 12257  44944     Sanford Santa Rita Pnt Nr  22.99               2
# 12258  45016  Neal One Lane Bridg Cab Svgn  93.99               2
# 12259  46011       Folonari Pnt Nr Venezie  12.99               2
# 12260  46964     Calera Viognier Mt Harlan  35.99               2
#
#        PurchasePrice  VendorNumber                   VendorName
# 0               9.28          8320  SHAW ROSS INT L IMP LTD
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           12261 non-null  int64
#  1   Description     12260 non-null  object
#  2   Price           12261 non-null  float64
#  3   Classification  12261 non-null  int64
#  4   PurchasePrice   12261 non-null  float64
#  5   VendorNumber    12261 non-null  int64
#  6   VendorName      12261 non-null  object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 670.7+ KB

# %%
df['Price'] = df['Price'] * 93.08

# %%
df['Price'].round(2)
# Out:
# 0        1209.11
# 1        3443.03
# 2        3629.19
# 3        3256.87
# 4        1395.27
#           ...
# 12256    2326.07
# 12257    2139.91
# 12258    8748.59
# 12259    1209.11
# 12260    3349.95
# Name: Price, Length: 12261, dtype: float64

# %%
df['PurchasePrice'] = df['PurchasePrice'] * 93.08

# %%
df[["Price", "PurchasePrice"]] = df[["Price", "PurchasePrice"]].round(2)

# %%
df
# Out:
#        Brand                   Description    Price  Classification  \
# 0         58   Gekkeikan Black & Gold Sake  1209.11               1
# 1         62      Herradura Silver Tequila  3443.03               1
# 2         63    Herradura Reposado Tequila  3629.19               1
# 3         72          No. 3 London Dry Gin  3256.87               1
# 4         75     Three Olives Tomato Vodka  1395.27               1
# ...      ...                           ...      ...             ...
# 12256  44917     Ferreira 10-Yr Tawny Port  2326.07               2
# 12257  44944     Sanford Santa Rita Pnt Nr  2139.91               2
# 12258  45016  Neal One Lane Bridg Cab Svgn  8748.59               2
# 12259  46011       Folonari Pnt Nr Venezie  1209.11               2
# 12260  46964     Calera Viognier Mt Harlan  3349.95               2
#
#        PurchasePrice  VendorNumber                   VendorName
# 0             863.78          8320  SHAW ROSS INT L IMP LTD
# ...

# %%
amountSpentInPercentage = (df['PurchasePrice']/df['Price']) * 100
discountedPrice = 100 - amountSpentInPercentage

discountedPrice

df['DiscountApplied'] = discountedPrice

# %%
df
# Out:
#        Brand                   Description    Price  Classification  \
# 0         58   Gekkeikan Black & Gold Sake  1209.11               1
# 1         62      Herradura Silver Tequila  3443.03               1
# 2         63    Herradura Reposado Tequila  3629.19               1
# 3         72          No. 3 London Dry Gin  3256.87               1
# 4         75     Three Olives Tomato Vodka  1395.27               1
# ...      ...                           ...      ...             ...
# 12256  44917     Ferreira 10-Yr Tawny Port  2326.07               2
# 12257  44944     Sanford Santa Rita Pnt Nr  2139.91               2
# 12258  45016  Neal One Lane Bridg Cab Svgn  8748.59               2
# 12259  46011       Folonari Pnt Nr Venezie  1209.11               2
# 12260  46964     Calera Viognier Mt Harlan  3349.95               2
#
#        PurchasePrice  VendorNumber                   VendorName  \
# 0             863.78          8320  SHAW ROSS INT L IMP LTD
# ...

# %%
df = df.drop(axis=1, columns="DiscountApplied")

# %%
df
# Out:
#        Brand                   Description    Price  Classification  \
# 0         58   Gekkeikan Black & Gold Sake  1209.11               1
# 1         62      Herradura Silver Tequila  3443.03               1
# 2         63    Herradura Reposado Tequila  3629.19               1
# 3         72          No. 3 London Dry Gin  3256.87               1
# 4         75     Three Olives Tomato Vodka  1395.27               1
# ...      ...                           ...      ...             ...
# 12256  44917     Ferreira 10-Yr Tawny Port  2326.07               2
# 12257  44944     Sanford Santa Rita Pnt Nr  2139.91               2
# 12258  45016  Neal One Lane Bridg Cab Svgn  8748.59               2
# 12259  46011       Folonari Pnt Nr Venezie  1209.11               2
# 12260  46964     Calera Viognier Mt Harlan  3349.95               2
#
#        PurchasePrice  VendorNumber                   VendorName
# 0             863.78          8320  SHAW ROSS INT L IMP LTD
# ...

# %%
df.insert(5, "DiscountApplied", discountedPrice)

# %%
df
# Out:
#        Brand                   Description    Price  Classification  \
# 0         58   Gekkeikan Black & Gold Sake  1209.11               1
# 1         62      Herradura Silver Tequila  3443.03               1
# 2         63    Herradura Reposado Tequila  3629.19               1
# 3         72          No. 3 London Dry Gin  3256.87               1
# 4         75     Three Olives Tomato Vodka  1395.27               1
# ...      ...                           ...      ...             ...
# 12256  44917     Ferreira 10-Yr Tawny Port  2326.07               2
# 12257  44944     Sanford Santa Rita Pnt Nr  2139.91               2
# 12258  45016  Neal One Lane Bridg Cab Svgn  8748.59               2
# 12259  46011       Folonari Pnt Nr Venezie  1209.11               2
# 12260  46964     Calera Viognier Mt Harlan  3349.95               2
#
#        PurchasePrice  DiscountApplied  VendorNumber  \
# 0             863.78        28.560677          8320
# ...

# %%
df['DiscountApplied'] = df['DiscountApplied'].round(2)

# %%
df
# Out:
#        Brand                   Description    Price  Classification  \
# 0         58   Gekkeikan Black & Gold Sake  1209.11               1
# 1         62      Herradura Silver Tequila  3443.03               1
# 2         63    Herradura Reposado Tequila  3629.19               1
# 3         72          No. 3 London Dry Gin  3256.87               1
# 4         75     Three Olives Tomato Vodka  1395.27               1
# ...      ...                           ...      ...             ...
# 12256  44917     Ferreira 10-Yr Tawny Port  2326.07               2
# 12257  44944     Sanford Santa Rita Pnt Nr  2139.91               2
# 12258  45016  Neal One Lane Bridg Cab Svgn  8748.59               2
# 12259  46011       Folonari Pnt Nr Venezie  1209.11               2
# 12260  46964     Calera Viognier Mt Harlan  3349.95               2
#
#        PurchasePrice  DiscountApplied  VendorNumber  \
# 0             863.78            28.56          8320
# ...

# %%
df.isnull().sum()
# Out:
# Brand              0
# Description        1
# Price              0
# Classification     0
# PurchasePrice      0
# DiscountApplied    1
# VendorNumber       0
# VendorName         0
# dtype: int64
