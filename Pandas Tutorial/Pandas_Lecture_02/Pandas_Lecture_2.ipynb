# %% [markdown]
# # ***Inserting Data From Our Local Device***

# %%
import pandas as pd
# Reading CSV file through the pandas -
df = pd.read_csv("./sample_data/california_housing_test.csv")
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
# if we want to target a specific column then try this -

df['latitude']
df['longitude']


pops = df['population'].sum()
print(int(pops))
# Out:
# 4208396

# %%
# to type-cast the exsisting data we must have to use some methods like -

df.to_json("housing_data.json")
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
# targeting multiple columns in pandas DF
newTable = df[['total_rooms', 'total_bedrooms', 'median_income', 'median_house_value']]
newTable
# Out:
#       total_rooms  total_bedrooms  median_income  median_house_value
# 0          3885.0           661.0         6.6085            344700.0
# 1          1510.0           310.0         3.5990            176500.0
# 2          3589.0           507.0         5.7934            270500.0
# 3            67.0            15.0         6.1359            330000.0
# 4          1241.0           244.0         2.9375             81700.0
# ...           ...             ...            ...                 ...
# 2995       1450.0           642.0         1.1790            225000.0
# 2996       5257.0          1082.0         3.3906            237200.0
# 2997        956.0           201.0         2.2895             62000.0
# 2998         96.0            14.0         3.2708            162500.0
# 2999       1765.0           263.0         8.5608            500001.0
#
# [3000 rows x 4 columns]

# %%
# to iterate the first 15 rows of data we can use df.head() method for the top rows of the data and df.tail() for the bottom rows of the data

print(df.head())     # by default .head() will provide only 5 rows of the df, if we want to get more than 5 rows of data we must have to pass a numerical argument in the df
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
print(df.head(15))     # by default .head() will provide only 5 rows of the df, if we want to get more than 5 rows of data we must have to pass a numerical argument in the df
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.05     37.37                27.0       3885.0           661.0
# 1     -118.30     34.26                43.0       1510.0           310.0
# 2     -117.81     33.78                27.0       3589.0           507.0
# 3     -118.36     33.82                28.0         67.0            15.0
# 4     -119.67     36.33                19.0       1241.0           244.0
# 5     -119.56     36.51                37.0       1018.0           213.0
# 6     -121.43     38.63                43.0       1009.0           225.0
# 7     -120.65     35.48                19.0       2310.0           471.0
# 8     -122.84     38.40                15.0       3080.0           617.0
# 9     -118.02     34.08                31.0       2402.0           632.0
# 10    -118.24     33.98                45.0        972.0           249.0
# 11    -119.12     35.85                37.0        736.0           166.0
# ...

# %%
print(df.tail())
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
print(df.tail(15))
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2986    -118.25     33.93                42.0        819.0           233.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2988    -122.01     36.97                43.0       2162.0           509.0
# 2989    -122.02     37.60                32.0       1295.0           295.0
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# ...
